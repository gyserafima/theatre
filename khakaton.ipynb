# %%
import json
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import random
random.seed = 23

# %%
from IPython.display import Image
Image("hello world!.jpg")

# %%
with open('dj.json', encoding="utf-8") as f:
    f = f.read()
    data = json.loads(f)

# %%
print(data[0]['data'])
# Out:
# {'sublect_id': 10, 'subject_name': 'Респ. Адыгея', 'kopuk': '040563', 'theatre_name': 'Национальный театр Республики Адыгея', 'theatre_genre': 'Драматические театры', 'composition_id': 9897035, 'composition_name': 'Заклинаю-помните', 'authors': 'Исупов Т.', 'composition_genre': 'Прочие виды и жанры драмтеатра', 'historically_national_attribute': 'Российские национальные произведения', 'nationally_territorial_attribute': 'Адыгея', 'spectator_age': 'Для юношества', 'subordination': 'Местное', 'composition_premiere': '1712', 'number_of_performances,_total': 21, 'number_of_performances,_stationary': 16, 'number_of_spetators,_total': 2.67, 'number_of_spetators,_stationary': 2.21}

# %%
info = []
s_ns = []
theatres = []
num_performances = []
#num_spectators = []
#genres = []
composition_names = []
for i in data:
    s_n = (i['data']['subject_name'])
    s_ns.append(s_n)
    theatre = (i['data']['theatre_name'])
    theatres.append(theatre)
    num_performance = (i['data']['number_of_performances,_stationary'])
    num_performances.append(num_performance)
    compose_name = (i['data']['composition_name'])
    composition_names.append(compose_name)
    info.append((s_n, theatres, num_performances, composition_names))

# %% [markdown]
# ### Количество спектаклей в регионах

# %%
lala = Counter(s_ns).most_common(21)

# %%
df = pd.DataFrame(lala)
df.drop([0,0], inplace=True)

# %%
df
# Out:
#                              0     1
# 1            г.Санкт-Петербург  1132
# 2              Московская обл.   725
# 3            Свердловская обл.   535
# 4             Челябинская обл.   520
# 5            Красноярский край   464
# 6              Респ. Татарстан   455
# 7           Нижегородская обл.   445
# 8               Самарская обл.   438
# 9                  Омская обл.   399
# 10          Респ. Башкортостан   397
# 11            Саратовская обл.   394
# 12               Пермский край   375
# 13          Волгоградская обл.   358
# 14             Ростовская обл.   347
# 15              Иркутская обл.   310
# 16          Новосибирская обл.   307
# 17  Кемеровская обл. - Кузбасс   272
# 18   Ханты-Мансийский а.о-Югра   257
# 19              Респ. Марий Эл   234
# 20         Респ. Саха (Якутия)   228

# %%
X = df[0]
Y = df[1]
plt.bar(X, Y, color='violet')
#plt.xticks(ticks=X, labels=POS)
plt.title('20 регионов по количеству спектаклей, без Москвы')
plt.ylabel('Количество спектаклей')
plt.xlabel('Регион')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Популярные жанры

# %%
from IPython.display import Image
Image("wineman.jpg")

# %%
c_gs = []
for i in data:
    c_g = (i['data']['composition_genre'])
    c_gs.append(c_g)

# %%
c_gs

# %%
genrs = Counter(c_gs).most_common(10)

# %%
df = pd.DataFrame(genrs)
#df.drop([0,0], inplace=True)

# %%
df
# Out:
#                     0     1
# 0              Сказка  6250
# 1             Комедия  2833
# 2               Драма  2073
# 3        Инсценировка  1266
# 4               Пьеса   679
# 5               Опера   585
# 6               Балет   574
# 7  Музыкальная сказка   562
# 8        Трагикомедия   495
# 9              Мюзикл   355

# %%
vals = df[1]
labels = df[0]
fig, ax = plt.subplots()
ax.pie(vals, labels=labels)
ax.axis("equal")
# Out:
# (-1.111163328110621,
#  1.1005315870528867,
#  -1.1019798612618745,
#  1.1175941884876386)

# %% [markdown]
# ### Самые популярные представления

# %%
#composition names - названия спектаклей
c_ns = []
for i in data:
    c_n = (i['data']['composition_name'])
    c_ns.append(c_n)

# %%
spectacles = Counter(c_ns).most_common(20)

# %%
df = pd.DataFrame(spectacles)
df
# Out:
#                                      0    1
# 0                              Концерт  246
# 1             Новогоднее представление  228
# 2       Театрализованное представление  161
# 3                              Золушка  118
# 4                        Кот в сапогах  110
# 5                     Снежная королева  103
# 6                              Морозко   97
# 7                           Дюймовочка   96
# 8                    Аленький цветочек   92
# 9                              Теремок   87
# 10                    Золотой цыпленок   84
# 11                  По щучьему велению   81
# 12                          Кошкин дом   79
# 13                         Гуси-лебеди   72
# 14                       Три поросенка   70
# 15                              Сказки   69
# 16                   Ромео и Джульетта   66
# 17                            Женитьба   65
# 18                              Ханума   63
# 19  Литературно-музыкальная композиция   61

# %%
vals = df[1]
labels = df[0]
fig, ax = plt.subplots()
ax.pie(vals, labels=labels, wedgeprops=dict(width=0.5))
# Out:
# ([<matplotlib.patches.Wedge at 0x1c0ce76d160>,
#   <matplotlib.patches.Wedge at 0x1c0ce76d668>,
#   <matplotlib.patches.Wedge at 0x1c0ce76db00>,
#   <matplotlib.patches.Wedge at 0x1c0ce76df98>,
#   <matplotlib.patches.Wedge at 0x1c0ce77c470>,
#   <matplotlib.patches.Wedge at 0x1c0ce77c908>,
#   <matplotlib.patches.Wedge at 0x1c0ce77cda0>,
#   <matplotlib.patches.Wedge at 0x1c0ce789278>,
#   <matplotlib.patches.Wedge at 0x1c0ce789710>,
#   <matplotlib.patches.Wedge at 0x1c0ce789ba8>,
#   <matplotlib.patches.Wedge at 0x1c0ce73fbe0>,
#   <matplotlib.patches.Wedge at 0x1c0ce7964e0>,
#   <matplotlib.patches.Wedge at 0x1c0ce796978>,
#   <matplotlib.patches.Wedge at 0x1c0ce796e10>,
#   <matplotlib.patches.Wedge at 0x1c0ce7a32e8>,
#   <matplotlib.patches.Wedge at 0x1c0ce7a3780>,
#   <matplotlib.patches.Wedge at 0x1c0ce7a3c18>,
#   <matplotlib.patches.Wedge at 0x1c0ce7b00f0>,
#   <matplotlib.patches.Wedge at 0x1c0ce7b0588>,
#   <matplotlib.patches.Wedge at 0x1c0ce7b0a20>],
#  [Text(1.0226049854274994, 0.4053135129487096, 'Концерт'),
#   Text(0.4945724626200673, 0.982546731315067, 'Новогоднее представление'),
#   Text(-0.14302114499445656, 1.0906626206506185, 'Театрализованное представление'),
#   Text(-0.5827839871549242, 0.932932379283627, 'Золушка'),
#   Text(-0.867181070389267, 0.6767547496386896, 'Кот в сапогах'),
#   Text(-1.0385102843404, 0.3626243087814462, 'Снежная королева'),
#   Text(-1.0995328256514243, 0.03205565964061319, 'Морозко'),
#   Text(-1.061048772618794, -0.29013014687231453, 'Дюймовочка'),
#   Text(-0.934715944800938, -0.5799190482600912, 'Аленький цветочек'),
#   Text(-0.7424578107122135, -0.8116380962673124, 'Теремок'),
#   Text(-0.5065925820540639, -0.9764035824431395, 'Золотой цыпленок'),
#   Text(-0.24594793215276892, -1.0721518617573618, 'По щучьему велению'),
#   Text(0.021934471406666035, -1.0997812868766728, 'Кошкин дом'),
#   Text(0.2738203663202918, -1.0653743037018593, 'Гуси-лебеди'),
#   Text(0.49758454595714746, -0.9810247803315774, 'Три поросенка'),
#   Text(0.6939121525912667, -0.8535138689477486, 'Сказки'),
#   Text(0.8545773122405559, -0.6926020628064198, 'Ромео и Джульетта'),
#   Text(0.9756253306737763, -0.5080897697727091, 'Женитьба'),
#   Text(1.0560023603114326, -0.30799190738830046, 'Ханума'),
#   Text(1.0951877820190938, -0.10277996943032291, 'Литературно-музыкальная композиция')])

# %% [markdown]
# ### Количество театров в регионах

# %%
List = []
for i in data: 
    d = {i['data']['subject_name']:i['data']['theatre_name']}
    if d in List:
        continue
    else:
        List.append(d)

# %%
List_2 = []
for d in List:
    List_2.append(list(d.keys())[0])

# %%
sb = Counter(List_2).most_common(20)

# %%
df = pd.DataFrame(sb)
df
# Out:
#                       0   1
# 0              г.Москва  94
# 1     г.Санкт-Петербург  35
# 2       Московская обл.  27
# 3     Свердловская обл.  17
# 4      Челябинская обл.  16
# 5       Респ. Татарстан  15
# 6        Самарская обл.  15
# 7     Красноярский край  14
# 8    Респ. Башкортостан  13
# 9    Нижегородская обл.  13
# 10       Респ. Дагестан  12
# 11        Пермский край  12
# 12     Саратовская обл.  12
# 13   Волгоградская обл.  11
# 14  Респ. Саха (Якутия)  10
# 15       Иркутская обл.  10
# 16   Новосибирская обл.  10
# 17          Омская обл.  10
# 18      Ростовская обл.   9
# 19     Воронежская обл.   8

# %%
X = df[0]
Y = df[1]
plt.bar(X, Y, color='yellow')
#plt.xticks(ticks=X, labels=POS)
plt.title('20 регионов по количеству театров в них')
plt.ylabel('Количество театров')
plt.xlabel('Регион')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Где больше все зрителей

# %%
#где больше всего зрителей ходят на спектакли
d = {}
for i in data:
    if i['data']['subject_name'] in d.keys():
        d[i['data']['subject_name']] += round(i['data']['number_of_spetators,_total'], 0)
    else:
        d[i['data']['subject_name']] = round(i['data']['number_of_spetators,_total'], 0)

# %%
visits = Counter(d).most_common(20)

# %%
df = pd.DataFrame(visits)
df
# Out:
#                              0       1
# 0                     г.Москва  7957.0
# 1            г.Санкт-Петербург  4184.0
# 2            Свердловская обл.  1187.0
# 3              Московская обл.  1123.0
# 4           Новосибирская обл.   960.0
# 5           Респ. Башкортостан   950.0
# 6            Красноярский край   919.0
# 7              Респ. Татарстан   913.0
# 8               Самарская обл.   864.0
# 9                Пермский край   856.0
# 10            Челябинская обл.   806.0
# 11          Нижегородская обл.   771.0
# 12             Ростовская обл.   726.0
# 13                 Омская обл.   642.0
# 14            Саратовская обл.   627.0
# 15             Приморский край   548.0
# 16          Краснодарский край   539.0
# 17              Иркутская обл.   535.0
# 18  Кемеровская обл. - Кузбасс   505.0
# 19          Волгоградская обл.   495.0

# %%
X = df[0]
Y = df[1]
plt.bar(X, Y, color='orange')
plt.title('Количество зрителей в областях')
plt.ylabel('Количество зрителей')
plt.xlabel('Регион')
plt.xticks(rotation=90)
plt.show()

# %%
from IPython.display import Image
Image("photo_2020-05-15_16-55-35.jpg")
